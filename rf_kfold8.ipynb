# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score, recall_score, precision_score, f1_score

import matplotlib.pyplot as plt

df = pd.DataFrame(pd.read_csv("acoustic_Features.csv"))
X = df.drop(["Class"], axis = 1)
y = df["Class"]

# %%
accuracy_list = []
tot_accuracy_list = []

tot_accuracy = 0
avg_accuracy = 0


kfold = KFold(n_splits=8, shuffle=True)
for m in [50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000]:
    for k in range(1,8):
        df_model = RandomForestClassifier(max_depth=k, n_estimators=m)
        for i in range(10):
            accuracy_list.append(cross_val_score(df_model, X, y, cv = kfold, scoring=(make_scorer(accuracy_score))).mean())
            
        
        for i in accuracy_list:
            tot_accuracy += i
        
        
        avg_accuracy = tot_accuracy / 10
        tot_accuracy_list.append(avg_accuracy)
        accuracy_list.clear()
        tot_accuracy = 0
        avg_accuracy = 0

# %% [markdown]
# 115m 12.4s

# %%
tot_accuracy_list
# Out:
# [0.6537499999999999,
#  0.7230000000000001,
#  0.75725,
#  0.7830000000000001,
#  0.79,
#  0.8032499999999999,
#  0.79125,
#  0.6702499999999999,
#  0.7344999999999999,
#  0.775,
#  0.7815000000000001,
#  0.8025,
#  0.8015000000000001,
#  0.804,
#  0.6667500000000001,
#  0.738,
#  0.7702500000000001,
#  0.7897500000000001,
#  0.7967500000000001,
#  0.80175,
#  0.8039999999999999,
#  0.6685,
#  0.732,
#  0.7745,
#  0.7885000000000001,
#  0.7997500000000001,
#  0.806,
#  0.80475,
#  0.67375,
#  0.735,
#  0.7737499999999999,
#  0.797,
#  0.80175,
#  0.80525,
#  0.8062500000000001,
#  0.67025,
#  0.737,
#  0.77525,
#  0.7962499999999999,
#  0.8025,
#  0.8015000000000001,
#  0.80175,
#  0.661,
#  0.7375,
#  0.77125,
#  0.7932500000000001,
#  0.8015000000000001,
#  0.804,
#  0.8012500000000001,
#  0.65625,
#  0.7324999999999999,
#  0.77525,
#  0.7935000000000001,
#  0.7989999999999999,
#  0.80525,
#  0.806,
#  0.6674999999999999,
#  0.7420000000000001,
#  0.77525,
#  0.7899999999999999,
#  0.8045000000000002,
#  0.8022500000000001,
#  0.80425,
#  0.66075,
#  0.741,
#  0.7735000000000001,
#  0.7955000000000001,
#  0.79925,
#  0.8072500000000001,
#  0.805,
#  0.67425,
#  0.736,
#  0.778,
#  0.7914999999999999,
#  0.7975000000000001,
#  0.8067499999999999,
#  0.8030000000000002,
#  0.6615,
#  0.7362500000000001,
#  0.7717500000000002,
#  0.793,
#  0.8007500000000001,
#  0.8,
#  0.8072500000000001,
#  0.6667500000000001,
#  0.736,
#  0.7782500000000001,
#  0.7929999999999999,
#  0.80325,
#  0.80475,
#  0.80575,
#  0.6575,
#  0.7339999999999999,
#  0.7737499999999999,
#  0.79525,
#  0.7985,
#  0.8015000000000001,
#  0.8065,
#  0.66425,
#  0.7332500000000001,
#  0.7707499999999999,
#  0.7927500000000001,
#  0.8010000000000002,
#  0.80725,
#  0.8090000000000002,
#  0.66575,
#  0.7340000000000002,
#  0.77575,
#  0.7935000000000001,
#  0.8019999999999999,
#  0.8115000000000002,
#  0.8089999999999999,
#  0.6705,
#  0.7397499999999999,
#  0.7764999999999999,
#  0.792,
#  0.8012499999999999,
#  0.80325,
#  0.807,
#  0.66025,
#  0.7482499999999999,
#  0.7789999999999999,
#  0.7987500000000001,
#  0.7975000000000001,
#  0.80525,
#  0.8099999999999999,
#  0.6620000000000001,
#  0.7462500000000001,
#  0.7705,
#  0.7925,
#  0.80325,
#  0.8087500000000001,
#  0.8085000000000001,
#  0.663,
#  0.7377499999999999,
#  0.7772499999999999,
#  0.7905000000000001,
#  0.8007500000000001,
#  0.80325,
#  0.8049999999999999]

# %%
X_new = df[["_Zero-crossingrate_Mean", "_HarmonicChangeDetectionFunction_Std", "_HarmonicChangeDetectionFunction_PeriodAmp", "_Fluctuation_Mean"]]

# %%
X_new
# Out:
#      _Zero-crossingrate_Mean  _HarmonicChangeDetectionFunction_Std  \
# 0                    403.129                                 0.261
# 1                    204.886                                 0.211
# 2                    685.474                                 0.299
# 3                    579.859                                 0.265
# 4                    430.536                                 0.261
# ..                       ...                                   ...
# 395                  493.908                                 0.140
# 396                  975.308                                 0.127
# 397                  916.985                                 0.157
# 398                  670.306                                 0.144
# 399                  396.386                                 0.110
#
#      _HarmonicChangeDetectionFunction_PeriodAmp  _Fluctuation_Mean
# 0                                         0.593              9.136
# 1                                         0.702              6.680
# 2                                         0.692             10.578
# 3                                         0.743             10.442
# 4                                         0.674              9.769
# ..                                          ...                ...
# 395                                       0.867              5.265
# 396                                       0.879              5.042
# 397                                       0.819              4.724
# 398                                       0.811              4.470
# 399                                       0.848              5.343
#
# [400 rows x 4 columns]

# %%
accuracy_list = []
tot_accuracy_list = []

tot_accuracy = 0
avg_accuracy = 0


kfold = KFold(n_splits=8, shuffle=True)
for m in [50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000]:
    for k in range(1,8):
        df_model = RandomForestClassifier(max_depth=k, n_estimators=m)
        for i in range(10):
            accuracy_list.append(cross_val_score(df_model, X_new, y, cv = kfold, scoring=(make_scorer(accuracy_score))).mean())
            
        
        for i in accuracy_list:
            tot_accuracy += i
        
        
        avg_accuracy = tot_accuracy / 10
        tot_accuracy_list.append(avg_accuracy)
        accuracy_list.clear()
        tot_accuracy = 0
        avg_accuracy = 0

# %%
accuracy_list2 = []
tot_accuracy_list2 = []

tot_accuracy2 = 0
avg_accuracy2 = 0

f1_list2 = []
tot_f1_list2 = []

tot_f12 = 0
avg_f12 = 0

precision_list2 = []
tot_precision_list2 = []

tot_precision2 = 0
avg_precision2 = 0

recall_list2 = []
tot_recall_list2 = []

tot_recall2 = 0
avg_recall2 = 0


kfold2 = KFold(n_splits=8, shuffle=True)

df_model2 = RandomForestClassifier(max_depth=6, n_estimators=800)
for i in range(10):
            accuracy_list2.append(cross_val_score(df_model2, X, y, cv = kfold2, scoring=(make_scorer(accuracy_score))).mean())
            f1_list2.append(cross_val_score(df_model2, X, y, cv = kfold2, scoring=(make_scorer(f1_score, average = "weighted"))).mean())
            precision_list2.append(cross_val_score(df_model2, X, y, cv = kfold2, scoring=(make_scorer(precision_score, average = "weighted"))).mean())
            recall_list2.append(cross_val_score(df_model2, X, y, cv = kfold2, scoring=(make_scorer(recall_score, average = "weighted"))).mean())
            
        
for i in accuracy_list2:
    tot_accuracy2 += i

avg_accuracy2 = tot_accuracy2 / 10

for i in f1_list2:
    tot_f12 += i

avg_f12 = tot_f12 / 10

for i in precision_list2:
    tot_precision2 += i

avg_precision2 = tot_precision2 / 10

for i in recall_list2:
    tot_recall2 += i

avg_recall2 = tot_recall2 / 10

# %%
avg_accuracy2
# Out:
# 0.8092499999999999

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
df_model3 = RandomForestClassifier(max_depth=6, n_estimators=800).fit(X_train, y_train)
y_pred = df_model3.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7833333333333333

# %%
importance = pd.DataFrame({"importance": df_model3.feature_importances_*1000}, index = X.columns)
importance.sort_values(by = "importance", axis = 0, ascending= True).plot(kind = "barh", color = "blue", fontsize=15, figsize=(20,20))

import matplotlib.pyplot as plt 
plt.xlabel("Importances of variables");
